# %%
with open('file.txt', 'wb') as file:
    file.write(b"Ali, 12-3-20, S1, S2,S3\n
    Fahad 14-04-22, S1, S2, S7,S3\n
    Ali 20-4-22 S1, S2\n
    Sara 20-4-22 S1, S7, S9\n
    Amina 20-4-22 S1")

# %%
# import pandas library
import pandas as pd

# create a list of lists from the given data
data = [
    ["Ali", "12-3-20", "S1, S2, S3"],
    ["Fahad", "14-04-22", "S1, S2, S7, S3"],
    ["Ali", "20-4-22", "S1, S2"],
    ["Sara", "20-4-22", "S1, S7, S9"],
    ["Amina", "20-4-22", "S1"]
]

# create a list of column names
columns = ["Username", "Date", "list of song IDs"]

# create a data frame from the list of lists and the column names
df = pd.DataFrame(data, columns=columns)

# print the data frame
display(df)
# Out:
#   Username      Date list of song IDs
# 0      Ali   12-3-20       S1, S2, S3
# 1    Fahad  14-04-22   S1, S2, S7, S3
# 2      Ali   20-4-22           S1, S2
# 3     Sara   20-4-22       S1, S7, S9
# 4    Amina   20-4-22               S1

# %%
# %run user_songs.py song_list.txt
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\AB\anaconda3\lib\logging\__init__.py", line 1086, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Users\AB\anaconda3\lib\codecs.py", line 378, in write
#     self.stream.write(data)
#   File "C:\Users\AB\AppData\Roaming\Python\Python39\site-packages\ipykernel\iostream.py", line 546, in write
#     raise TypeError(msg)
# TypeError: write() argument must be str, not <class 'bytes'>
# Call stack:
#   File "C:\Users\AB\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\AB\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\AB\AppData\Roaming\Python\Python39\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\AB\AppData\Roaming\Python\Python39\site-packages\traitlets\config\application.py", line 1041, in launch_instance
# ...
